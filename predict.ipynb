# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
 
from utils import build_model

# %%
img = mpimg.imread('find_phone/9.jpg')/255.

# %%
model = build_model(img.shape)
model.load_weights('models/41-295.03.h5')
# Out:
# 2023-03-03 17:35:08.696408: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 3503292416 exceeds 10% of free system memory.

# %%
img_ = np.expand_dims(img, axis=0)

# %%
y_pred = model.predict(img_)
y_pred
# Out:
# 1/1 [==============================] - 0s 32ms/step
# array([[177.74754,  95.30503]], dtype=float32)

# %%
plt.plot(y_pred[0][0],y_pred[0][1],'r.')
plt.imshow(img)
